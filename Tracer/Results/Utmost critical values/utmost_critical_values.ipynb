# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
xs = [0.0, 0.09, 0.17, 0.25, 0.33, 0.39, 0.43, 0.5, 0.58, 0.67, 0.75, 0.83, 0.91]
gs = [4.115, 4.16, 4.28, 4.5, 4.895, 6.441, 9.003, 16.463, 7.121, 5.361, 4.308, 3.541, 2.963]

# %%
plt.figure(figsize=(20, 12))
plt.rcParams.update({'font.size': 18})
plt.xticks(xs)
plt.xlabel('$x_0$')
plt.ylabel('$\gamma_*$', rotation='horizontal', position=(0.0, 0.45))
plt.grid()
plt.scatter(xs, gs, s=80, zorder=2)
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,1.8,y2))
plt.savefig('C:/_Repositories/KaschenkoEquation/Tracer/Results/Origins/x0-gamma_star.png')
